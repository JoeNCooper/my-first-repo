# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot as plt

# %%
file_path ='jumta.csv' 
df = pd.read_csv(r'C:\Users\PSI-313\Desktop\Africa School  Folder\jumta.csv')
df
# Out:
#      Month Revenue  Orders  Average_Order_Value
# 0   Jan-20  10,000     200                   50
# 1   Feb-20  11,000     220                   50
# 2   Mar-20  12,000     240                   50
# 3   Apr-20  13,000     260                   50
# 4   May-20  14,000     280                   50
# 5   Jun-20  15,000     300                   50
# 6   Jul-20  16,000     320                   50
# 7   Aug-20  17,000     340                   50
# 8   Sep-20  18,000     360                   50
# 9   Oct-20  19,000     380                   50
# 10  Nov-20  20,000     400                   50
# 11  Dec-20  21,000     420                   50
# 12  Jan-21  22,000     440                   50
# 13  Feb-21  23,000     460                   50
# 14  Mar-21  24,000     480                   50
# 15  Apr-21  25,000     500                   50
# 16  May-21  26,000     520                   50
# 17  Jun-21  27,000     540                   50
# 18  Jul-21  28,000     560                   50
# ...

# %% [markdown]
# 1. Create a line plot showing the monthly revenue over the two-year period. Customize the plot to make it publication-quality

# %%
x =[10000,11000,12000,13000,14000,15000,16000,17000,18000,19000,20000,21000,22000,23000,24000,25000,26000,
     27000,28000,29000,30000,31000,32000,33000]
y =['Jan-20','Feb-20','Mar-20','Apr-20','May-20','Jun-20', 'Jul-20','Aug-20','Sep-20','Oct-20','Nov-20','Dec-20','Jan-21','Feb-21','Mar-21','Apr-21',
            'May-21','Jun-21','Jul-21','Aug-21','Sep-21','Oct-21','Nov-21','Dec-21']

plt.xlabel("REVENUE")
plt.ylabel("MONTH")
plt.plot(x,y, color="Green")
plt.title('Line Plot')
plt.show()

# %% [markdown]
# Create a bar plot showing the total number of orders per month. Customize the plot to make it publication-quality.

# %%
x = [200,220,240,260,280,300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660] 
y = ['Jan-20','Feb-20','Mar-20','Apr-20','May-20','Jun-20', 'Jul-20','Aug-20','Sep-20','Oct-20','Nov-20','Dec-20','Jan-21','Feb-21','Mar-21','Apr-21',
            'May-21','Jun-21','Jul-21','Aug-21','Sep-21','Oct-21','Nov-21','Dec-21'] 

plt.xlabel("ORDER")
plt.ylabel("MONTH")
plt.bar(x,y, width=12, color="Maroon")
plt.title('Bar plot')
plt.show()

# %% [markdown]
# •	Create a scatter plot showing the relationship between the number of orders and the average order value. Customize the plot to make it publication-quality

# %%
x = [200,220,240,260,280,300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660] 
y = [50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,] 


plt.xlabel("ORDER")
plt.ylabel("ORDER VALUE")
plt.scatter(x,y, color='green')
plt.title('Scatterplot')
plt.show()

# %% [markdown]
# •	Create a subplot containing all three visualizations created in steps 2-4. Adjust the layout and size of the subplot to make it visually appealing.

# %%
x =[10000,11000,12000,13000,14000,15000,16000,17000,18000,19000,20000,21000,22000,23000,24000,25000,26000,
     27000,28000,29000,30000,31000,32000,33000]
y =['Jan-20','Feb-20','Mar-20','Apr-20','May-20','Jun-20', 'Jul-20','Aug-20','Sep-20','Oct-20','Nov-20','Dec-20','Jan-21','Feb-21','Mar-21','Apr-21',
            'May-21','Jun-21','Jul-21','Aug-21','Sep-21','Oct-21','Nov-21','Dec-21']
plt.subplot(2,2,1)
plt.plot(x,y)

x = [200,220,240,260,280,300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660] 
y = ['Jan-20','Feb-20','Mar-20','Apr-20','May-20','Jun-20', 'Jul-20','Aug-20','Sep-20','Oct-20','Nov-20','Dec-20','Jan-21','Feb-21','Mar-21','Apr-21',
            'May-21','Jun-21','Jul-21','Aug-21','Sep-21','Oct-21','Nov-21','Dec-21'] 

plt.subplot(2,2,2)
plt.plot(x,y)

x = [200,220,240,260,280,300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660] 
y = [50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,] 

plt.subplot(2,2,3)
plt.plot(x,y)
